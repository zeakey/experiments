# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import torch

# %%
checkpoint = torch.load('tmp/resnet18-affine23-cifar/checkpoint.pth')
params = checkpoint["state_dict"]

# %%
for name in params:
    if "affine" in name:
        print(name)
# Out:
# layer2.1.affine.weight
# layer3.1.affine.weight

# %%
plt.imshow(params["layer2.1.affine.weight"], cmap=cm.jet)

# %%
plt.imshow(params["layer3.1.affine.weight"], cmap=cm.jet)
